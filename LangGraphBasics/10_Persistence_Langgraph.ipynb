# %%
# Here we are using the same Skeleton of chatbot and improving it by adding loops and conditions to store the chat history.
from langgraph.graph import StateGraph,START,END
from langchain_openai import ChatOpenAI
from typing import TypedDict, Literal
import operator
from typing import List,Annotated
from dotenv import load_dotenv
from langgraph.checkpoint.memory import InMemorySaver

# %%
load_dotenv()

llm=ChatOpenAI()

# %%
class JokeState(TypedDict):
    topic:str
    joke:str
    explanation:str

# %%
def generate_joke(state:JokeState):
    prompt=f"generate a joke for the topic :{state['topic']}"
    result=llm.invoke(prompt).content
    return {'joke':result}

def generate_explanation(state:JokeState):
    prompt=f"generate a explanation for the joke :{state['joke']}"
    result=llm.invoke(prompt).content
    return {'explanation': result}

# %%
graph =StateGraph(JokeState)
graph.add_node('generate_joke',generate_joke)
graph.add_node('generate_explanation',generate_explanation)

graph.add_edge(START,'generate_joke')
graph.add_edge('generate_joke','generate_explanation')
graph.add_edge('generate_explanation',END)

#now build the checkpointer object for InMemorySaver class 
checkpointer=InMemorySaver()


workflow=graph.compile(checkpointer=checkpointer)


#Now create a threadId for this conversation
config={'configurable':{'thread_id':'1'}} 
workflow.invoke({'topic':"pizza"},config=config)
# Out:
# {'topic': 'pizza',
#  'joke': "Why did the pizza go to the party alone? Because it didn't want to be too cheesy!",
#  'explanation': 'This joke plays on the double meaning of the word "cheesy." In one sense, cheesy can refer to having characteristics of cheese, which is often associated with pizza. In another sense, cheesy can also mean corny or overly sentimental. So, in this joke, the pizza decided to go to the party alone because it didn\'t want to be too cheesy in the sense of being overly corny or sentimental.'}

# %%
workflow.get_state(config)
# Out:
# StateSnapshot(values={'topic': 'pizza', 'joke': "Why did the pizza go to the party alone? Because it didn't want to be too cheesy!", 'explanation': 'This joke plays on the double meaning of the word "cheesy." In one sense, cheesy can refer to having characteristics of cheese, which is often associated with pizza. In another sense, cheesy can also mean corny or overly sentimental. So, in this joke, the pizza decided to go to the party alone because it didn\'t want to be too cheesy in the sense of being overly corny or sentimental.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e1658-26e2-62fa-8002-ab571527ea80'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-12-25T07:44:14.468786+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e1658-1947-6fab-8001-f62204c74c5d'}}, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config)) # this will give all the intermediate state history of the graph
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': "Why did the pizza go to the party alone? Because it didn't want to be too cheesy!", 'explanation': 'This joke plays on the double meaning of the word "cheesy." In one sense, cheesy can refer to having characteristics of cheese, which is often associated with pizza. In another sense, cheesy can also mean corny or overly sentimental. So, in this joke, the pizza decided to go to the party alone because it didn\'t want to be too cheesy in the sense of being overly corny or sentimental.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e1658-26e2-62fa-8002-ab571527ea80'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-12-25T07:44:14.468786+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e1658-1947-6fab-8001-f62204c74c5d'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': "Why did the pizza go to the party alone? Because it didn't want to be too cheesy!"}, next=('generate_explanation',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e1658-1947-6fab-8001-f62204c74c5d'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2025-12-25T07:44:13.042474+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e1658-0e66-6b4e-8000-8f788cfbfaaf'}}, tasks=(PregelTask(id='74253267-30d9-74ef-5b94-d31c9352f746', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke plays on the double meaning of the word "cheesy." In one sense, cheesy can refer to having characteristics of cheese, which is often associated with pizza. In another sense, cheesy can also mean corny or overly sentimental. So, in this joke, the pizza decided to go to the party alone because it didn\'t want to be too cheesy in the sense of being overly corny or sentimental.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e1658-0e66-6b4e-8000-8f788cfbfaaf'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2025-12-25T07:44:11.901627+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e1658-0e64-6451-bfff-c8f5bcf9fed7'}}, tasks=(PregelTask(id='256f7149-ea97-4b1f-fbdb-86b876f69d43', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': "Why did the pizza go to the party alone? Because it didn't want to be too cheesy!"}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e1658-0e64-6451-bfff-c8f5bcf9fed7'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2025-12-25T07:44:11.900628+00:00', parent_config=None, tasks=(PregelTask(id='a575b195-7ff7-7077-508a-c4e3d47a3d94', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=())]

# %%
config2={'configurable':{'thread_id':'2'}}
workflow.invoke({'topic':'Cricket'},config=config2)
# Out:
# {'topic': 'Cricket',
#  'joke': 'Why did the cricket team go to the library? \n\nBecause they wanted to learn how to improve their googly!',
#  'explanation': 'This joke is based on the wordplay of "googly," which is a term used in cricket to describe a type of ball delivery that spins in the opposite direction to what the batsman expects. The joke suggests that the cricket team went to the library to learn how to improve their googly by studying and researching different techniques and strategies.'}

# %%
workflow.get_state(config2) # for the thread_id=2 this entire data stored in the saparate memory
# Out:
# StateSnapshot(values={'topic': 'Cricket', 'joke': 'Why did the cricket team go to the library? \n\nBecause they wanted to learn how to improve their googly!', 'explanation': 'This joke is based on the wordplay of "googly," which is a term used in cricket to describe a type of ball delivery that spins in the opposite direction to what the batsman expects. The joke suggests that the cricket team went to the library to learn how to improve their googly by studying and researching different techniques and strategies.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0e1660-ac84-6896-8002-c4e02e025121'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-12-25T07:48:03.229711+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0e1660-9b4f-6aad-8001-16656aecb5ad'}}, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config2))
# Out:
# [StateSnapshot(values={'topic': 'Cricket', 'joke': 'Why did the cricket team go to the library? \n\nBecause they wanted to learn how to improve their googly!', 'explanation': 'This joke is based on the wordplay of "googly," which is a term used in cricket to describe a type of ball delivery that spins in the opposite direction to what the batsman expects. The joke suggests that the cricket team went to the library to learn how to improve their googly by studying and researching different techniques and strategies.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0e1660-ac84-6896-8002-c4e02e025121'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-12-25T07:48:03.229711+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0e1660-9b4f-6aad-8001-16656aecb5ad'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'Cricket', 'joke': 'Why did the cricket team go to the library? \n\nBecause they wanted to learn how to improve their googly!'}, next=('generate_explanation',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0e1660-9b4f-6aad-8001-16656aecb5ad'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2025-12-25T07:48:01.425476+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0e1660-90eb-66f0-8000-23d255cea3bf'}}, tasks=(PregelTask(id='47b21fdd-5ae7-1083-48db-9802db9b7983', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke is based on the wordplay of "googly," which is a term used in cricket to describe a type of ball delivery that spins in the opposite direction to what the batsman expects. The joke suggests that the cricket team went to the library to learn how to improve their googly by studying and researching different techniques and strategies.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'Cricket'}, next=('generate_joke',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0e1660-90eb-66f0-8000-23d255cea3bf'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2025-12-25T07:48:00.335844+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0e1660-90e8-6e8a-bfff-a42c005a06fe'}}, tasks=(PregelTask(id='633b2480-91b8-0d70-78fc-27bd30b96fe3', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the cricket team go to the library? \n\nBecause they wanted to learn how to improve their googly!'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0e1660-90e8-6e8a-bfff-a42c005a06fe'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2025-12-25T07:48:00.334810+00:00', parent_config=None, tasks=(PregelTask(id='3db384f9-e92c-22ba-ab2e-af4617aa0f0d', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'Cricket'}),), interrupts=())]
