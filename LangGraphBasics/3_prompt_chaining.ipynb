# %%
from langgraph.graph import StateGraph,START,END
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from typing import TypedDict
load_dotenv()
model=ChatOpenAI()

# %%
#define the state
class BlogState(TypedDict):
    topic:str
    outline:str
    blog:str

# %%
def create_outline(state:BlogState)->BlogState:
    #fetch title, call llm to get outline, update the blog of the state
    topic=state['topic']
    prompt=f'create a outline for the topic:{topic}'
    state['outline']=model.invoke(prompt).content
    return state

# %%
def create_blog(state:BlogState)->BlogState:
    #fetch title, call llm to get outline, update the blog of the state
    topic=state['topic']
    outline=state['outline']
    prompt=f'create a detailed blog for the topic:{topic}using the followint outline \n {outline}'
    state['blog']=model.invoke(prompt).content
    return state

# %%
graph = StateGraph(BlogState)

graph.add_node('create_outline',create_outline)
graph.add_node('create_blog',create_blog)

graph.add_edge(START,'create_outline')
graph.add_edge('create_outline','create_blog')
graph.add_edge('create_blog',END)

workflow=graph.compile()
initial_state={'topic':"BMW"}
final_state=workflow.invoke(initial_state)
print(final_state['outline'])
print(final_state['blog'])
# Out:
# I. Introduction
#    A. Brief history of BMW
#    B. Overview of BMW's reputation and popularity
#
# II. BMW's product line
#    A. Cars
#       1. Sedans
#       2. SUVs
#       3. Electric vehicles
#    B. Motorcycles
#    C. Performance vehicles (such as the M series)
#
# III. BMW's innovative technology and features
#    A. Connected drive and infotainment systems
#    B. Advanced driver assistance systems
#    C. Efficient dynamics and sustainability initiatives
#
# IV. BMW's global presence and market share
#    A. Sales figures by region
#    B. Competition with other luxury automakers
#
# V. BMW's brand image and marketing strategies
#    A. Target demographic
#    B. Sponsorships and partnerships
#    C. Advertising campaigns
#
# VI. Challenges and controversies faced by BMW
#    A. Recalls and quality control issues
#    B. Environmental concerns
#    C. Impact of global market trends on the automotive industry
#
# VII. Conclusion
#    A. Summary of key points
#    B. Future outlook for BMW in the automotive industry.
#
# I. Introduction
#
# A. Brief history of BMW
# BMW, which stands for Bayerische Motoren Werke AG, was founded in 1916 as a manufacturer of aircraft engines. The company later transitioned to producing motorcycles in 1923 and then automobiles in 1928. Since then, BMW has become one of the most renowned and iconic luxury car brands in the world.
#
# B. Overview of BMW's reputation and popularity
# BMW is known for producing high-performance and luxurious vehicles that cater to a discerning clientele. The brand has built a reputation for quality, innovation, and cutting-edge technology, making it a highly desirable choice for car enthusiasts and luxury buyers alike.
#
# II. BMW's product line
#
# A. Cars
# BMW offers a diverse range of cars, including sedans, SUVs, electric vehicles, and performance vehicles. The brand's lineup includes popular models such as the BMW 3 Series, X5, i3, and M series performance cars.
#
# B. Motorcycles
# In addition to cars, BMW also produces a line of high-quality motorcycles known for their performance and precision engineering.
#
# C. Performance vehicles
# The M series is BMW's line of high-performance vehicles, known for their powerful engines, aggressive styling, and track-ready capabilities.
#
# III. BMW's innovative technology and features
#
# A. Connected drive and infotainment systems
# BMW vehicles are equipped with state-of-the-art infotainment systems that provide connectivity, navigation, and entertainment options for drivers and passengers.
#
# B. Advanced driver assistance systems
# BMW has incorporated advanced driver assistance systems into its vehicles, such as adaptive cruise control, lane-keeping assist, and automatic parking, to enhance safety and convenience on the road.
#
# C. Efficient dynamics and sustainability initiatives
# BMW is committed to sustainability and reducing its carbon footprint through initiatives such as electrification, lightweight construction, and efficient powertrain technologies.
#
# IV. BMW's global presence and market share
#
# A. Sales figures by region
# BMW has a strong global presence, with a significant market share in Europe, North America, and Asia. The brand's sales figures reflect its popularity and success in key markets around the world.
#
# B. Competition with other luxury automakers
# BMW faces stiff competition from other luxury automakers, such as Mercedes-Benz, Audi, and Lexus, in the global automotive market. The brand continuously strives to innovate and differentiate itself to maintain its competitive edge.
#
# V. BMW's brand image and marketing strategies
#
# A. Target demographic
# BMW targets a diverse demographic of luxury buyers, ranging from young professionals to affluent families. The brand's image is often associated with sophistication, performance, and status.
#
# B. Sponsorships and partnerships
# BMW has established partnerships with various sports teams, events, and cultural institutions to enhance its brand image and engage with consumers.
#
# C. Advertising campaigns
# BMW's advertising campaigns are known for their creativity, innovation, and emotional appeal, showcasing the brand's vehicles in dynamic and aspirational settings.
#
# VI. Challenges and controversies faced by BMW
#
# A. Recalls and quality control issues
# BMW has faced challenges related to recalls and quality control issues in the past, affecting the brand's reputation and customer trust.
#
# B. Environmental concerns
# As a leading automotive manufacturer, BMW faces growing scrutiny and pressure to address environmental concerns, such as emissions standards, sustainability practices, and electric vehicle adoption.
#
# C. Impact of global market trends on the automotive industry
# BMW must navigate the evolving landscape of the automotive industry, including technological advancements, changing consumer preferences, and geopolitical factors that influence market dynamics.
#
# VII. Conclusion
#
# A. Summary of key points
# BMW is a renowned luxury car brand with a rich history, innovative technology, and a strong global presence. The brand's reputation for quality, performance, and luxury has solidified its position as a top competitor in the automotive industry.
#
# B. Future outlook for BMW in the automotive industry
# As BMW continues to innovate and adapt to market trends, the brand is well-positioned to maintain its relevance and leadership in the luxury automotive sector. With a focus on sustainability, technology, and customer experience, BMW is poised for continued success in the future.

# %%
graph.compile()
